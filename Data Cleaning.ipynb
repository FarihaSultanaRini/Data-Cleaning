# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
tree_census=pd.read_csv("2015_Street_Tree_Census_-_Tree_Data.csv")
tree_census
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset=tree_census[['tree_id','tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin',  'steward',
       'sidewalk',  'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]

tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
tree_census_subset.isnull().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isnull()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset[tree_census_subset['health'].isnull()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset[tree_census_subset['spc_latin'].isnull()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset[tree_census_subset['steward'].isnull()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset[tree_census_subset['problems'].isnull()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subset.hist(bins=60,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
tree_census_subset[tree_census_subset['tree_id']>683788]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 406172   695621         0           5          OnCurb  Stump    NaN
# 438584   689927         0          25          OnCurb  Stump    NaN
# 438798   694166         2           0          OnCurb   Dead    NaN
# 439751   684009         0          30          OnCurb  Stump    NaN
# 439769   684011         5           0          OnCurb   Dead    NaN
# ...         ...       ...         ...             ...    ...    ...
# 518639   691855         3           0          OnCurb  Alive   Good
# 518640   713340         4           0          OnCurb  Alive   Good
# 518642   718320         5           0  OffsetFromCurb  Alive   Good
# 518643   718331         4           0  OffsetFromCurb  Alive   Good
# 518646   718538         7           0          OnCurb  Alive   Good
#
#                 spc_latin steward  sidewalk      problems root_stone  \
# 406172                NaN     NaN       NaN           NaN         No
# ...

# %%
tree_census_subset['tree_id'].count()
# Out:
# 683788

# %%
big_trees=tree_census_subset[tree_census_subset['tree_dbh']>50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675265   179496        52           0  OffsetFromCurb  Alive   Good
# 677954   166796        54           0          OnCurb  Alive   Good
# 679894   169501        51           0          OnCurb  Alive   Good
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin steward  sidewalk      problems  \
# ...

# %%
big_trees[['tree_id','tree_dbh']].plot(kind="scatter",x='tree_id',y='tree_dbh',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='tree_dbh'>

# %%
tree_census_subset[tree_census_subset['stump_diam']>130]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 11342    206819         0         140   OnCurb  Stump    NaN       NaN
# 89539    286364         0         134   OnCurb  Stump    NaN       NaN
# 137315   319640         0         131   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 11342      NaN      NaN      NaN         No         No         No         No
# 89539      NaN      NaN      NaN         No         No         No         No
# 137315     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 11342          No         No         No        No         No
# 89539          No         No         No        No         No
# 137315         No         No         No        No         No

# %%
bigtrees_stump=tree_census_subset[tree_census_subset['stump_diam']>50]
bigtrees_stump
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 6122     200925         0          52   OnCurb  Stump    NaN       NaN
# 6177     200924         0          55   OnCurb  Stump    NaN       NaN
# 6466     166008         0          72   OnCurb  Stump    NaN       NaN
# 7042     206818         0         100   OnCurb  Stump    NaN       NaN
# 9872     192215         0          53   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 645994   135904         0          65   OnCurb  Stump    NaN       NaN
# 646336   151125         0          55   OnCurb  Stump    NaN       NaN
# 649174   154188         0          65   OnCurb  Stump    NaN       NaN
# 652690   154181         0          60   OnCurb  Stump    NaN       NaN
# 653066   154190         0          80   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
bigtrees_stump[['tree_id','stump_diam']].plot(kind="scatter",x='tree_id',y='stump_diam',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='stump_diam'>

# %%
tree_census_subset['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
pd.DataFrame(tree_census_subset['spc_latin'].value_counts()).plot(kind='bar',figsize=(25,15))
# Out:
# <AxesSubplot:>

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
tree_census_subset['problems'].value_counts()
# Out:
# None                                                                          426280
# Stones                                                                         95673
# BranchLights                                                                   29452
# Stones,BranchLights                                                            17808
# RootOther                                                                      11418
#                                                                                ...
# Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# MetalGrates,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther               1
# MetalGrates,WiresRope,TrunkLights,BranchLights,BranchOther                         1
# Stones,MetalGrates,TrunkLights,TrunkOther                                          1
# MetalGrates,TrunkOther,Sneakers                                                    1
# Name: problems, Length: 232, dtype: int64

# %%
tree_census_subset['health'].value_counts()
# Out:
# Good    528850
# Fair     96504
# Poor     26818
# Name: health, dtype: int64

# %%
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# OnCurb            656896
# OffsetFromCurb     26892
# Name: curb_loc, dtype: int64

# %%
tree_census_subset['status'].value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
tree_census_subset['health'].value_counts()
# Out:
# Good    528850
# Fair     96504
# Poor     26818
# Name: health, dtype: int64

# %%
tree_census_subset['root_stone'].value_counts()
# Out:
# No     543789
# Yes    139999
# Name: root_stone, dtype: int64

# %%
tree_census_subset['root_grate'].value_counts()
# Out:
# No     680252
# Yes      3536
# Name: root_grate, dtype: int64

# %%
tree_census_subset['trunk_wire'].value_counts()
# Out:
# No     670514
# Yes     13274
# Name: trunk_wire, dtype: int64

# %%
tree_census_subset['trnk_light'].value_counts()
# Out:
# No     682757
# Yes      1031
# Name: trnk_light, dtype: int64

# %%
tree_census_subset['trnk_other'].value_counts()
# Out:
# No     651215
# Yes     32573
# Name: trnk_other, dtype: int64

# %%
tree_census_subset['brch_light'].value_counts()
# Out:
# No     621423
# Yes     62365
# Name: brch_light, dtype: int64

# %%
tree_census_subset['brch_shoe'].value_counts()
# Out:
# No     683377
# Yes       411
# Name: brch_shoe, dtype: int64

# %%
tree_census_subset['brch_other'].value_counts()
# Out:
# No     659433
# Yes     24355
# Name: brch_other, dtype: int64

# %%
tree_census_subset['problems'].value_counts()
# Out:
# None                                                                          426280
# Stones                                                                         95673
# BranchLights                                                                   29452
# Stones,BranchLights                                                            17808
# RootOther                                                                      11418
#                                                                                ...
# Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# MetalGrates,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther               1
# MetalGrates,WiresRope,TrunkLights,BranchLights,BranchOther                         1
# Stones,MetalGrates,TrunkLights,TrunkOther                                          1
# MetalGrates,TrunkOther,Sneakers                                                    1
# Name: problems, Length: 232, dtype: int64

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
tree_probs=tree_census_subset[['root_stone','root_grate','root_other','trunk_wire','trnk_light','trnk_other','brch_light','brch_shoe','brch_other']]
tree_probs
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
tree_probs.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %%
#pd.set_option('display.max_rows',None)
pd.reset_option('display.max_rows', silent=True)

prob_Tyeps=tree_census_subset['problems'].value_counts()

# %%
prob_Tyeps
# Out:
# None                                                                          426280
# Stones                                                                         95673
# BranchLights                                                                   29452
# Stones,BranchLights                                                            17808
# RootOther                                                                      11418
#                                                                                ...
# Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# MetalGrates,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther               1
# MetalGrates,WiresRope,TrunkLights,BranchLights,BranchOther                         1
# Stones,MetalGrates,TrunkLights,TrunkOther                                          1
# MetalGrates,TrunkOther,Sneakers                                                    1
# Name: problems, Length: 232, dtype: int64

# %%
df=prob_Tyeps.copy()

# %%
prob_Tyeps.compare(df)
# Out:
# Empty DataFrame
# Columns: [self, other]
# Index: []

# %%
#pd.set_option('display.max_rows',None)
#pd.reset_option('display.max_rows', silent=True)

prob_Tyeps=tree_census_subset['problems'].value_counts()
prob_Tyeps
# Out:
# None                                                                                               426280
# Stones                                                                                              95673
# BranchLights                                                                                        29452
# Stones,BranchLights                                                                                 17808
# RootOther                                                                                           11418
# TrunkOther                                                                                          11143
# BranchOther                                                                                          8352
# Stones,TrunkOther                                                                                    5183
# Stones,RootOther                                                                                     4468
# ...

# %%
tree_census_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683788 entries, 0 to 683787
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   tree_id     683788 non-null  int64
#  1   tree_dbh    683788 non-null  int64
#  2   stump_diam  683788 non-null  int64
#  3   curb_loc    683788 non-null  object
#  4   status      683788 non-null  object
#  5   health      652172 non-null  object
#  6   spc_latin   652169 non-null  object
#  7   steward     652173 non-null  object
#  8   sidewalk    652172 non-null  object
#  9   problems    652124 non-null  object
#  10  root_stone  683788 non-null  object
#  11  root_grate  683788 non-null  object
#  12  root_other  683788 non-null  object
#  13  trunk_wire  683788 non-null  object
#  14  trnk_light  683788 non-null  object
#  15  trnk_other  683788 non-null  object
#  16  brch_light  683788 non-null  object
#  17  brch_shoe   683788 non-null  object
# ...
